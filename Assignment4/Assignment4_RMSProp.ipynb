# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data_root = '/content/drive/My Drive/dataset1'

# %%
from keras.preprocessing.image import ImageDataGenerator 
from keras.models import Sequential 
from keras.layers import Conv2D, MaxPooling2D 
from keras.layers import Activation, Dropout, Flatten, Dense ,BatchNormalization
from keras import backend as K 
import numpy as np
from keras.optimizers import *
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
img_width, img_height = 150, 150
  
train_data_dir = '/content/drive/My Drive/dataset1/train'
validation_data_dir = '/content/drive/My Drive/dataset1/test'
train_samples = 880
validation_samples = 220
epochs = 20
batch_size = 10
filter_pixel=3

# %%
from keras import backend as K 
if K.image_data_format() == 'channels_first': 
    input_shape = (3, img_width, img_height) 
else: 
    input_shape = (img_width, img_height, 3)

# %%
train_datagen = ImageDataGenerator( 
                rotation_range=20.,
                width_shift_range=0.1,
                height_shift_range=0.1,
                shear_range=0.2,
                zoom_range=0.2,
                horizontal_flip=True,
                vertical_flip=True) 
  
test_datagen = ImageDataGenerator(rescale = 1. / 255) 
  
train_generator = train_datagen.flow_from_directory(train_data_dir, 
                              target_size =(img_width, img_height), 
                     batch_size = batch_size, class_mode ='categorical') 
  
validation_generator = test_datagen.flow_from_directory( 
                                    validation_data_dir, 
                   target_size =(img_width, img_height), 
          batch_size = batch_size, class_mode ='categorical')
# Out:
# Found 2640 images belonging to 3 classes.
# Found 660 images belonging to 3 classes.

# %%
model = Sequential()

model.add(Conv2D(64, kernel_size=(filter_pixel, filter_pixel), padding="same",
                 activation='relu',
                 input_shape=input_shape))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3,3), activation='relu',border_mode="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3,3), activation='relu',border_mode="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.25))

model.add(Flatten()) 
model.add(Dense(3,use_bias=False)) 
model.add(BatchNormalization())
model.add(Activation('relu')) 
model.add(Dropout(0.25))      

model.add(Dense(3)) 
model.add(Activation('softmax'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(3, 3), activation="relu", padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(3, 3), activation="relu", padding="same")`
#   app.launch_new_instance()

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 150, 150, 64)      1792
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 150, 150, 64)      256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 150, 150, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 150, 150, 64)      36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 150, 150, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 75, 75, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 75, 75, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 37, 37, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 87616)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 262848
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 3)                 12
# _________________________________________________________________
# activation_1 (Activation)    (None, 3)                 0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 12
# _________________________________________________________________
# activation_2 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 339,288
# Trainable params: 338,898
# Non-trainable params: 390
# _________________________________________________________________

# %%
opt = RMSprop(lr=0.1,decay=1e-2)
model.compile(optimizer=opt, loss='categorical_crossentropy',
                   metrics=['categorical_accuracy'])

# %%
from keras.utils import plot_model
plot_model(model,to_file='model.png')

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
model_path = './model.h5'
callbacks = [
    EarlyStopping(
        monitor='val_acc', 
        patience=10,
        mode='max',
        verbose=1),
    ModelCheckpoint(model_path,
        monitor='val_acc', 
        save_best_only=True, 
        mode='max',
        verbose=0)
]

# %%
history=  model.fit_generator(train_generator, 
    steps_per_epoch = train_samples, 
    epochs = 20, 
    validation_data = validation_generator,
    validation_steps = 50,
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 880/880 [==============================] - 1061s 1s/step - loss: 0.9148 - categorical_accuracy: 0.5483 - val_loss: 3.2845 - val_categorical_accuracy: 0.3360
# Epoch 2/20
#   2/880 [..............................] - ETA: 1:14 - loss: 0.6679 - categorical_accuracy: 0.7500
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: val_loss,val_categorical_accuracy,loss,categorical_accuracy
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 880/880 [==============================] - 103s 117ms/step - loss: 0.8000 - categorical_accuracy: 0.6200 - val_loss: 4.4345 - val_categorical_accuracy: 0.3440
# Epoch 3/20
# 880/880 [==============================] - 87s 99ms/step - loss: 0.7813 - categorical_accuracy: 0.6509 - val_loss: 3.8293 - val_categorical_accuracy: 0.3260
# Epoch 4/20
# 880/880 [==============================] - 86s 97ms/step - loss: 0.7481 - categorical_accuracy: 0.6757 - val_loss: 3.4241 - val_categorical_accuracy: 0.3420
# Epoch 5/20
# 880/880 [==============================] - 85s 96ms/step - loss: 0.7327 - categorical_accuracy: 0.6903 - val_loss: 6.3062 - val_categorical_accuracy: 0.3180
# Epoch 6/20
# 880/880 [==============================] - 84s 96ms/step - loss: 0.7102 - categorical_accuracy: 0.7025 - val_loss: 1.8195 - val_categorical_accuracy: 0.3400
# Epoch 7/20
# 880/880 [==============================] - 84s 96ms/step - loss: 0.7019 - categorical_accuracy: 0.7039 - val_loss: 9.8164 - val_categorical_accuracy: 0.3420
# Epoch 8/20
# 880/880 [==============================] - 84s 96ms/step - loss: 0.7050 - categorical_accuracy: 0.7023 - val_loss: 1.3818 - val_categorical_accuracy: 0.3360
# Epoch 9/20
# 880/880 [==============================] - 85s 96ms/step - loss: 0.7061 - categorical_accuracy: 0.7075 - val_loss: 5.3532 - val_categorical_accuracy: 0.3360
# Epoch 10/20
# 880/880 [==============================] - 84s 96ms/step - loss: 0.6868 - categorical_accuracy: 0.7141 - val_loss: 1.2883 - val_categorical_accuracy: 0.3020
# Epoch 11/20
# 880/880 [==============================] - 84s 96ms/step - loss: 0.6821 - categorical_accuracy: 0.7159 - val_loss: 1.8992 - val_categorical_accuracy: 0.3440
# Epoch 12/20
# 880/880 [==============================] - 85s 97ms/step - loss: 0.6705 - categorical_accuracy: 0.7237 - val_loss: 2.9653 - val_categorical_accuracy: 0.3540
# Epoch 13/20
# 880/880 [==============================] - 84s 95ms/step - loss: 0.6684 - categorical_accuracy: 0.7266 - val_loss: 4.2579 - val_categorical_accuracy: 0.3280
# Epoch 14/20
# 880/880 [==============================] - 84s 96ms/step - loss: 0.6479 - categorical_accuracy: 0.7364 - val_loss: 1.6484 - val_categorical_accuracy: 0.3400
# Epoch 15/20
# 880/880 [==============================] - 84s 96ms/step - loss: 0.6504 - categorical_accuracy: 0.7364 - val_loss: 1.6651 - val_categorical_accuracy: 0.3280
# Epoch 16/20
# 880/880 [==============================] - 84s 95ms/step - loss: 0.6697 - categorical_accuracy: 0.7257 - val_loss: 2.0453 - val_categorical_accuracy: 0.3400
# Epoch 17/20
# 880/880 [==============================] - 84s 95ms/step - loss: 0.6552 - categorical_accuracy: 0.7373 - val_loss: 2.7169 - val_categorical_accuracy: 0.3220
# Epoch 18/20
# 880/880 [==============================] - 84s 95ms/step - loss: 0.6674 - categorical_accuracy: 0.7336 - val_loss: 1.3713 - val_categorical_accuracy: 0.3360
# Epoch 19/20
# 880/880 [==============================] - 83s 94ms/step - loss: 0.6431 - categorical_accuracy: 0.7389 - val_loss: 1.3339 - val_categorical_accuracy: 0.3500
# Epoch 20/20
# 880/880 [==============================] - 84s 95ms/step - loss: 0.6502 - categorical_accuracy: 0.7406 - val_loss: 1.7290 - val_categorical_accuracy: 0.3220

# %%
import matplotlib.pyplot as plt 
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.ylabel('accuracy') 
plt.xlabel('epoch')
plt.legend()
plt.figure()
plt.plot(epochs, loss,'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('loss') 
plt.xlabel('epoch')
plt.legend()
plt.show()
