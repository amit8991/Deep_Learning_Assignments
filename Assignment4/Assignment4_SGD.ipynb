# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data_root = '/content/drive/My Drive/dataset1'

# %%
from keras.preprocessing.image import ImageDataGenerator 
from keras.models import Sequential 
from keras.layers import Conv2D, MaxPooling2D 
from keras.layers import Activation, Dropout, Flatten, Dense ,BatchNormalization
from keras import backend as K 
import numpy as np
from keras.optimizers import *
import pandas as pd
import matplotlib.pyplot as plt

# %%
img_width, img_height = 150, 150
  
train_data_dir = '/content/drive/My Drive/dataset1/train'
validation_data_dir = '/content/drive/My Drive/dataset1/test'
train_samples = 880
validation_samples = 220
epochs = 20
batch_size = 10
filter_pixel=3

# %%
from keras import backend as K 
if K.image_data_format() == 'channels_first': 
    input_shape = (3, img_width, img_height) 
else: 
    input_shape = (img_width, img_height, 3)

# %%
train_datagen = ImageDataGenerator( 
                rotation_range=20.,
                width_shift_range=0.1,
                height_shift_range=0.1,
                shear_range=0.2,
                zoom_range=0.2,
                horizontal_flip=True,
                vertical_flip=True) 
  
test_datagen = ImageDataGenerator(rescale = 1. / 255) 
  
train_generator = train_datagen.flow_from_directory(train_data_dir, 
                              target_size =(img_width, img_height), 
                     batch_size = batch_size, class_mode ='categorical') 
  
validation_generator = test_datagen.flow_from_directory( 
                                    validation_data_dir, 
                   target_size =(img_width, img_height), 
          batch_size = batch_size, class_mode ='categorical')
# Out:
# Found 2640 images belonging to 3 classes.
# Found 660 images belonging to 3 classes.

# %%
model = Sequential()

model.add(Conv2D(64, kernel_size=(filter_pixel, filter_pixel), padding="same",
                 activation='relu',
                 input_shape=input_shape))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3,3), activation='relu',border_mode="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3,3), activation='relu',border_mode="same"))
model.add(BatchNormalization())
model.add(MaxPooling2D())
model.add(Dropout(0.25))

model.add(Flatten()) 
model.add(Dense(3,use_bias=False)) 
model.add(BatchNormalization())
model.add(Activation('relu')) 
model.add(Dropout(0.25))      

model.add(Dense(3)) 
model.add(Activation('softmax'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(3, 3), activation="relu", padding="same")`
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(3, 3), activation="relu", padding="same")`

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 150, 150, 64)      1792
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 150, 150, 64)      256
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 150, 150, 64)      0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 150, 150, 64)      36928
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 150, 150, 64)      256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 75, 75, 64)        0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 75, 75, 64)        36928
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 75, 75, 64)        256
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 37, 37, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 87616)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 262848
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 3)                 12
# _________________________________________________________________
# activation_10 (Activation)   (None, 3)                 0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 3)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 12
# _________________________________________________________________
# activation_11 (Activation)   (None, 3)                 0
# =================================================================
# Total params: 339,288
# Trainable params: 338,898
# Non-trainable params: 390
# _________________________________________________________________

# %%
opt = SGD(lr=0.1, momentum=0.9, decay=1e-2)
model.compile(optimizer=opt, loss='categorical_crossentropy',
                   metrics=['categorical_accuracy'])

# %%
from keras.utils import plot_model
plot_model(model,to_file='model.png')

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
model_path = './model.h5'
callbacks = [
    EarlyStopping(
        monitor='val_acc', 
        patience=10,
        mode='max',
        verbose=1),
    ModelCheckpoint(model_path,
        monitor='val_acc', 
        save_best_only=True, 
        mode='max',
        verbose=0)
]

# %%
history=  model.fit_generator(train_generator, 
    steps_per_epoch = train_samples, 
    epochs = 20, 
    validation_data = validation_generator,
    validation_steps = 50,
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 880/880 [==============================] - 119s 135ms/step - loss: 0.9488 - categorical_accuracy: 0.5039 - val_loss: 1.2310 - val_categorical_accuracy: 0.3300
# Epoch 2/20
#   1/880 [..............................] - ETA: 1:55 - loss: 1.0374 - categorical_accuracy: 0.3000
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: val_loss,val_categorical_accuracy,loss,categorical_accuracy
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 880/880 [==============================] - 117s 133ms/step - loss: 0.8580 - categorical_accuracy: 0.5444 - val_loss: 1.2223 - val_categorical_accuracy: 0.3640
# Epoch 3/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.8282 - categorical_accuracy: 0.5761 - val_loss: 1.3396 - val_categorical_accuracy: 0.3280
# Epoch 4/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.7847 - categorical_accuracy: 0.6135 - val_loss: 1.1938 - val_categorical_accuracy: 0.3340
# Epoch 5/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.7746 - categorical_accuracy: 0.6258 - val_loss: 1.2372 - val_categorical_accuracy: 0.3320
# Epoch 6/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.7442 - categorical_accuracy: 0.6552 - val_loss: 1.4559 - val_categorical_accuracy: 0.3200
# Epoch 7/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.7491 - categorical_accuracy: 0.6611 - val_loss: 1.3735 - val_categorical_accuracy: 0.3360
# Epoch 8/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.7286 - categorical_accuracy: 0.6760 - val_loss: 0.9927 - val_categorical_accuracy: 0.3460
# Epoch 9/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.7118 - categorical_accuracy: 0.6802 - val_loss: 1.6987 - val_categorical_accuracy: 0.3300
# Epoch 10/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.7133 - categorical_accuracy: 0.6893 - val_loss: 1.2630 - val_categorical_accuracy: 0.3320
# Epoch 11/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.7182 - categorical_accuracy: 0.6895 - val_loss: 1.5444 - val_categorical_accuracy: 0.3240
# Epoch 12/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.7042 - categorical_accuracy: 0.6876 - val_loss: 1.3130 - val_categorical_accuracy: 0.3460
# Epoch 13/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.7002 - categorical_accuracy: 0.6968 - val_loss: 1.2204 - val_categorical_accuracy: 0.3240
# Epoch 14/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.7078 - categorical_accuracy: 0.6903 - val_loss: 1.3529 - val_categorical_accuracy: 0.3340
# Epoch 15/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.6912 - categorical_accuracy: 0.6973 - val_loss: 1.2292 - val_categorical_accuracy: 0.3400
# Epoch 16/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.6923 - categorical_accuracy: 0.6998 - val_loss: 1.3462 - val_categorical_accuracy: 0.3240
# Epoch 17/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.6961 - categorical_accuracy: 0.6984 - val_loss: 1.7028 - val_categorical_accuracy: 0.3360
# Epoch 18/20
# 880/880 [==============================] - 118s 134ms/step - loss: 0.6833 - categorical_accuracy: 0.7039 - val_loss: 1.4599 - val_categorical_accuracy: 0.3540
# Epoch 19/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.6831 - categorical_accuracy: 0.7036 - val_loss: 1.3679 - val_categorical_accuracy: 0.3120
# Epoch 20/20
# 880/880 [==============================] - 117s 133ms/step - loss: 0.6761 - categorical_accuracy: 0.7127 - val_loss: 1.7594 - val_categorical_accuracy: 0.3400

# %%
import matplotlib.pyplot as plt 
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.ylabel('accuracy') 
plt.xlabel('epoch')
plt.legend()
plt.figure()
plt.plot(epochs, loss,'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('loss') 
plt.xlabel('epoch')
plt.legend()
plt.show()
